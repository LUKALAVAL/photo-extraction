# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import csv
import json

# %%
original = cv2.imread("data/full_set/bpt6k683902h_1.jpg", cv2.IMREAD_GRAYSCALE)
plt.figure(figsize=(15, 10))
plt.imshow(original, cmap='gray')

# %%
image = original.copy()
image = image[100:400, 100:400]

# display the image and the magnitude spectrum of the image
plt.figure(figsize=(15, 10))
plt.subplot(211)
plt.imshow(image, cmap='gray')
plt.title('Input Image')
plt.subplot(212)
f = np.fft.fft2(image)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(np.abs(fshift))
plt.imshow(magnitude_spectrum)
plt.title('Magnitude Spectrum')
plt.show()

# %%
image = original.copy()
image = image[1700:2000, 1700:2000]

# display the image and the magnitude spectrum of the image
plt.figure(figsize=(15, 10))
plt.subplot(211)
plt.imshow(image, cmap='gray')
plt.title('Input Image')
plt.subplot(212)
f = np.fft.fft2(image)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(np.abs(fshift))
plt.imshow(magnitude_spectrum)
plt.title('Magnitude Spectrum')
plt.show()

# %%
image = original.copy()
image = image[1700:2000, 2000:2300]

# display the image and the magnitude spectrum of the image
plt.figure(figsize=(15, 10))
plt.subplot(211)
plt.imshow(image, cmap='gray')
plt.title('Input Image')
plt.subplot(212)
f = np.fft.fft2(image)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(np.abs(fshift))
plt.imshow(magnitude_spectrum)
plt.title('Magnitude Spectrum')
plt.show()

# %%
image = original.copy()
image = image[1700:2000, 1700:2000]

plt.figure(figsize=(15, 10))
plt.subplot(211)
plt.imshow(image, cmap='gray')
plt.title('Input Image')
plt.subplot(212)
f = np.fft.fft2(image)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(np.abs(fshift))
plt.imshow(magnitude_spectrum)
plt.title('Magnitude Spectrum')
plt.show()



image = original.copy()
image = image[1800:1900, 1800:1900]

plt.figure(figsize=(15, 10))
plt.subplot(211)
plt.imshow(image, cmap='gray')
plt.title('Input Image')
plt.subplot(212)
f = np.fft.fft2(image)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(np.abs(fshift))
plt.imshow(magnitude_spectrum)
plt.title('Magnitude Spectrum')
plt.show()



image = original.copy()
image = image[1850:1860, 1850:1860]

plt.figure(figsize=(15, 10))
plt.subplot(211)
plt.imshow(image, cmap='gray')
plt.title('Input Image')
plt.subplot(212)
f = np.fft.fft2(image)
fshift = np.fft.fftshift(f)
magnitude_spectrum = np.log(np.abs(fshift))
plt.imshow(magnitude_spectrum)
plt.title('Magnitude Spectrum')
plt.show()

# %%
padded_image = np.pad(image, ((0, image.shape[0] * 2), (0, image.shape[1] * 2)), mode='constant')

f_padded = np.fft.fft2(padded_image)
fshift_padded = np.fft.fftshift(f_padded)

magnitude_spectrum_padded = np.log(np.abs(fshift_padded))

plt.figure(figsize=(10, 10))

plt.subplot(221)
plt.imshow(image, cmap='gray')
plt.title('Original Image')

plt.subplot(222)
plt.imshow(magnitude_spectrum)
plt.title('Original Magnitude Spectrum')

plt.subplot(223)
plt.imshow(padded_image, cmap='gray')
plt.title('Padded Image')

plt.subplot(224)
plt.imshow(magnitude_spectrum_padded)
plt.title('Padded Magnitude Spectrum')

plt.show()
